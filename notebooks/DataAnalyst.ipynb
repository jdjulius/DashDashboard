# %%
import pandas as pd
import glob
import os

# Ruta de la carpeta que contiene los archivos CSV
carpeta = '../data/raw'

# %%
# Buscar todos los archivos CSV en la carpeta
archivos_csv = glob.glob(os.path.join(carpeta, "*.csv"))

# Leer y concatenar los archivos CSV en un único DataFrame
dataframes = [pd.read_csv(f) for f in archivos_csv]
df_concatenado = pd.concat(dataframes, ignore_index=True)

# Visualizar los primeros registros
print(df_concatenado.head())
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0   2000-717      Orlando    Clay       32.0             A    20000501.0  \
# 1   2000-717      Orlando    Clay       32.0             A    20000501.0
# 2   2000-717      Orlando    Clay       32.0             A    20000501.0
# 3   2000-717      Orlando    Clay       32.0             A    20000501.0
# 4   2000-717      Orlando    Clay       32.0             A    20000501.0
#
#    match_num  winner_id  winner_seed winner_entry  ... l_ace l_df  l_svpt
# 0        1.0   102179.0          NaN          NaN  ...  13.0  4.0   110.0  \
# 1        2.0   103602.0          NaN            Q  ...   0.0  0.0    57.0
# 2        3.0   103387.0          NaN          NaN  ...   2.0  2.0    65.0
# 3        4.0   101733.0          NaN          NaN  ...   4.0  6.0   104.0
# 4        5.0   101727.0          4.0          NaN  ...   0.0  3.0    47.0
#
#   l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced
# ...

# %%
df_concatenado.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0   2000-717      Orlando    Clay       32.0             A    20000501.0  \
# 1   2000-717      Orlando    Clay       32.0             A    20000501.0
# 2   2000-717      Orlando    Clay       32.0             A    20000501.0
# 3   2000-717      Orlando    Clay       32.0             A    20000501.0
# 4   2000-717      Orlando    Clay       32.0             A    20000501.0
#
#    match_num  winner_id  winner_seed winner_entry  ... l_ace l_df  l_svpt
# 0        1.0   102179.0          NaN          NaN  ...  13.0  4.0   110.0  \
# 1        2.0   103602.0          NaN            Q  ...   0.0  0.0    57.0
# 2        3.0   103387.0          NaN          NaN  ...   2.0  2.0    65.0
# 3        4.0   101733.0          NaN          NaN  ...   4.0  6.0   104.0
# 4        5.0   101727.0          4.0          NaN  ...   0.0  3.0    47.0
#
#   l_1stIn  l_1stWon  l_2ndWon  l_SvGms  l_bpSaved  l_bpFaced
# ...

# %%
df_concatenado.describe()
# Out:
#           draw_size  tourney_date     match_num      winner_id   winner_seed
# count  50179.000000  5.017900e+04  50179.000000   50179.000000  20797.000000  \
# mean      52.889675  2.007355e+07     26.463122  103912.882222      7.233062
# std       38.631478  4.600528e+04     26.815736    1623.111462      6.657105
# min        4.000000  2.000010e+07      1.000000  100644.000000      1.000000
# 25%       32.000000  2.003091e+07      7.000000  103176.000000      3.000000
# 50%       32.000000  2.007072e+07     19.000000  103888.000000      5.000000
# 75%       64.000000  2.011082e+07     32.000000  104597.000000      9.000000
# max      128.000000  2.015113e+07    127.000000  200537.000000     35.000000
#
#           winner_ht    winner_age   winner_rank  winner_rank_points
# count  47572.000000  50167.000000  49132.000000        49132.000000  \
# mean     185.565017     25.902493     82.338700         1494.859257
# std        6.726959      3.577284    145.924817         1936.672951
# ...

# %%
df_concatenado.columns
# Out:
# Index(['tourney_id', 'tourney_name', 'surface', 'draw_size', 'tourney_level',
#        'tourney_date', 'match_num', 'winner_id', 'winner_seed', 'winner_entry',
#        'winner_name', 'winner_hand', 'winner_ht', 'winner_ioc', 'winner_age',
#        'winner_rank', 'winner_rank_points', 'loser_id', 'loser_seed',
#        'loser_entry', 'loser_name', 'loser_hand', 'loser_ht', 'loser_ioc',
#        'loser_age', 'loser_rank', 'loser_rank_points', 'score', 'best_of',
#        'round', 'minutes', 'w_ace', 'w_df', 'w_svpt', 'w_1stIn', 'w_1stWon',
#        'w_2ndWon', 'w_SvGms', 'w_bpSaved', 'w_bpFaced', 'l_ace', 'l_df',
#        'l_svpt', 'l_1stIn', 'l_1stWon', 'l_2ndWon', 'l_SvGms', 'l_bpSaved',
#        'l_bpFaced',
# ...

# %%
# Guardar el DataFrame en un archivo CSV
df_concatenado.to_csv('../data/join/join.csv', index=False)

# %%
valores_unicos_lista = df_concatenado['winner_name'].unique().tolist()
print(valores_unicos_lista)
# Out:
# ['Antony Dupuis', 'Fernando Gonzalez', 'Paradorn Srichaphan', 'Jan Siemerink', 'Jason Stoltenberg', 'Jiri Vanek', 'Martin Rodriguez', 'Paul Goldstein', 'Nicolas Massu', 'Jan Kroslak', 'Michael Russell', 'Gianluca Pozzi', 'Razvan Sabau', 'Markus Hantschk', 'Xavier Malisse', 'Ramon Delgado', 'Andre Agassi', 'Michal Tabara', 'Jeff Tarango', 'Magnus Larsson', 'Sargis Sargsian', 'Chris Woodruff', 'Todd Woodbridge', 'Julian Alonso', 'Michael Chang', 'Andrew Ilie', 'Stephane Huet', 'Stefan Koubek', 'Yevgeny Kafelnikov', 'Daniel Vacek', 'Fabrice Santoro', 'Hicham Arazi', 'Mariano Zabaleta', 'Cyril Saulnier', 'Jerome Golmard', 'Greg Rusedski', 'Cedric Pioline', 'Karol Kucera', 'Thomas Enqvist', 'Dominik Hrbaty', 'Marc Rosset', 'Goran Ivanisevic', 'Roger Federer', 'Arnaud Clement', 'Wayne Ferreira', 'Arnaud Di Pasquale', 'Andrei Pavel', 'Nicolas Lapentti', 'Lleyton Hewitt', 'Julien Boutter', 'Jiri Novak', 'Byron Black', 'Marcelo Rios', 'Jens Knippschild', 'Pete Sampras', 'Justin Gimelstob', 'A
# ...

# %%
dff17 = pd.read_csv('../data/raw/atp_matches_2017.csv',delimiter=";")
dff17.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0  2017-M020     Brisbane    Hard         32             A      20170102  \
# 1  2017-M020     Brisbane    Hard         32             A      20170102
# 2  2017-M020     Brisbane    Hard         32             A      20170102
# 3  2017-M020     Brisbane    Hard         32             A      20170102
# 4  2017-M020     Brisbane    Hard         32             A      20170102
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df
# 0        300     105777          7.0          NaN  ...       7.0   4.0   0.0  \
# 1        299     105777          7.0          NaN  ...       0.0   4.0   3.0
# 2        298     105453          3.0          NaN  ...       5.0   9.0   2.0
# 3        297     105683          1.0          NaN  ...       7.0   4.0   0.0
# 4        296     105777          7.0          NaN  ...      14.0   6.0   5.0
#
# ...

# %%
dff16 = pd.read_csv('../data/raw/atp_matches_2016.csv',delimiter=";")
dff16.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0  2016-M020     Brisbane    Hard       32.0             A    20160104.0  \
# 1  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 2  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 3  2016-M020     Brisbane    Hard       32.0             A    20160104.0
# 4  2016-M020     Brisbane    Hard       32.0             A    20160104.0
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df
# 0      300.0   105683.0          4.0          NaN  ...       1.0   7.0   3.0  \
# 1      299.0   103819.0          1.0          NaN  ...       1.0   2.0   4.0
# 2      298.0   105683.0          4.0          NaN  ...       4.0  10.0   3.0
# 3      297.0   103819.0          1.0          NaN  ...       1.0   8.0   2.0
# 4      296.0   106233.0          8.0          NaN  ...       2.0  11.0   2.0
#
# ...

# %%
dff15 = pd.read_csv('../data/raw/atp_matches_2015.csv',delimiter=",")
dff15.head()
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date
# 0   2015-329        Tokyo    Hard         32             A      20151005  \
# 1   2015-329        Tokyo    Hard         32             A      20151005
# 2   2015-329        Tokyo    Hard         32             A      20151005
# 3   2015-329        Tokyo    Hard         32             A      20151005
# 4   2015-329        Tokyo    Hard         32             A      20151005
#
#    match_num  winner_id  winner_seed winner_entry  ... w_bpFaced l_ace  l_df
# 0          1     104527          1.0          NaN  ...       1.0   2.0   2.0  \
# 1          2     105147          NaN           WC  ...      14.0   1.0   4.0
# 2          3     105572          NaN            Q  ...       7.0  15.0   7.0
# 3          4     105311          NaN          NaN  ...       6.0   9.0   5.0
# 4          5     104468          3.0          NaN  ...       6.0   0.0   5.0
#
# ...
